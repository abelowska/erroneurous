# %% [markdown]
# # Results summary

# %% [markdown]
# ### Imports

# %%
import os
import re
import glob
import os
import ast
import os.path as op
from collections import defaultdict
from copy import deepcopy
import copy

import pickle
from time import time
import pywt
import mne
import scipy
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import cesium.featurize
from plotly.subplots import make_subplots
from ipywidgets import Dropdown, FloatRangeSlider, IntSlider, FloatSlider, interact
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.base import TransformerMixin, BaseEstimator

import sys

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.svm import SVR
from sklearn.decomposition import FastICA
from sklearn.decomposition import PCA

from rumination_experiment_transformers_averaged_CDS import *

import warnings

warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---
# ## Loading data
#
# Load pickled results

# %%
columns = ['mean_train_r2', 'mean_cv_r2', 'p-value', 'external_score',  'external_p-value' , 'scale', 'model']

# %%
rumination = "16-Rumination Full Scale"
dass_anxiety = "05-DASS-21 Anxiety scale"
stai_t = "04-STAI Trait SUM" 
bis = "07-BIS"
bas_dzialanie = "07-BAS Dzialanie"
bas_przyjemnosc = "07-BAS Poszukiwanie przyjemnosci"
bas_nagroda = "07-BAS Wrazliwosc na nagrode"
washing = "14-Obsessive-Compulsive WASHING"
obsessing = "14-Obsessive-Compulsive OBSESSING"
hoarding = "14-Obsessive-Compulsive HOARDING"
ordering = "14-Obsessive-Compulsive ORDERING"
checking = "14-Obsessive-Compulsive CHECKING"
neutralizing = "14-Obsessive-Compulsive NEUTRALIZING"
oci_r_full = "14-Obsessive-Compulsive FULL"
threat = "15-Obsessional Beliefs - Overestimation of threat"
perfectionism_IU = "15-Obsessional Beliefs - Perfectionism/ Intolerance of uncertainty"
thought_suppression = "18-Thought Suppression Inventory"
nonforgivness = "22-Nonforgiveness - Full Scale"
indecisivness = "27-Indecisiveness Scale_Frost"
IU_prospecitve = "28-Intolerance of Uncertainty - Prospective Anxiety"
IU_inhibitory = "28-Intolerance of Uncertainty - Inhibitory Anxiety"
self_esteem = "06-Self-Esteem Scale_SES Rosenberga"

scales = [
    self_esteem,
    rumination,
    dass_anxiety,
    stai_t,
    bis,
    washing,
    obsessing,
    hoarding,
    ordering,
    checking,
    neutralizing,
    oci_r_full,
    threat,
    thought_suppression,
    IU_prospecitve,
    IU_inhibitory,
]

scales_dict = {
    "16-Rumination Full Scale": "RRQ",
    "05-DASS-21 Anxiety scale": "DASS-21 Anx",
    "04-STAI Trait SUM": "STAI-T",
    "07-BIS": "BIS",
    "14-Obsessive-Compulsive WASHING": "Washing",
    "14-Obsessive-Compulsive OBSESSING": "Obsessing",
    "14-Obsessive-Compulsive HOARDING": "Hoarding",
    "14-Obsessive-Compulsive ORDERING": "Ordering",
    "14-Obsessive-Compulsive CHECKING": "Checking",
    "14-Obsessive-Compulsive NEUTRALIZING": "Neutralizing",
    "14-Obsessive-Compulsive FULL": "OCI-R",
    "15-Obsessional Beliefs - Overestimation of threat": "OT",
    "18-Thought Suppression Inventory": "WBSI",
    "28-Intolerance of Uncertainty - Prospective Anxiety": "IUS-P",
    "28-Intolerance of Uncertainty - Inhibitory Anxiety": "IUS-I",
    "06-Self-Esteem Scale_SES Rosenberga": "SES",
              }

# %%
results_ern = pd.read_pickle("../public_data/results/models_pickles/regression_union_100-600_cached_ern_amplitude_various_scales_with_external_p.pkl")
results_pe = pd.read_pickle("../public_data/results/models_pickles/regression_union_100-600_cached_pe_amplitude_various_scales_with_external_p.pkl")

# %%
results_ern_IU = pd.read_pickle("../public_data/results/models_pickles/regression_union_100-600_cached_ern_amplitude_various_scales_IU_with_external_p.pkl")
results_pe_IU = pd.read_pickle("../public_data/results/models_pickles/regression_union_100-600_cached_pe_amplitude_various_scales_IU_with_external_p.pkl")

# %% [markdown]
# ## ERN summary

# %%
# extract resulst of IU-Inhibitory experiment
results_ern_IU = results_ern_IU[results_ern_IU['scale'] == '28-Intolerance of Uncertainty - Inhibitory Anxiety'].iloc[-12:]
results_ern_IU[columns]
# Out:
#     mean_train_r2  mean_cv_r2   p-value  external_score  external_p-value  \
# 42       0.015048   -0.003498  0.028971       -0.130953          0.466533
# 43       0.067293   -0.026402  0.290709       -0.095979          0.959041
# 44       0.070784   -0.029344  0.312687       -0.101671          0.478521
# 45       0.127674   -0.019884  0.155844        0.005241          0.108891
# 46       0.175661    0.029852  0.021978        0.047695          0.084915
# 47       0.000000   -0.034134  0.447552       -0.010137          0.975025
# 48       0.155707    0.007049  0.052947        0.025843          0.092907
# 49       0.293927    0.137673  0.000999       -0.038856          0.156843
# 50       0.124229    0.036322  0.013986        0.056105          0.069930
# 51       0.567835   -0.007381  0.044955       -0.170057          0.204795
# 52       0.324621    0.073651  0.006993       -0.051381          0.175824
# 53       0.086266   -0.015889  0.139860        0.024212          0.123876
#
#                                                 scale model
# 42  28-Intolerance of Uncertainty - Inhibitory Anx...   svr
# 43  28-Intolerance of Uncertainty - Inhibitory Anx...    kr
# 44  28-Intolerance of Uncertainty - Inhibitory Anx...    en
# 45  28-Intolerance of Uncertainty - Inhibitory Anx...   svr
# 46  28-Intolerance of Uncertainty - Inhibitory Anx...    kr
# 47  28-Intolerance of Uncertainty - Inhibitory Anx...    en
# 48  28-Intolerance of Uncertainty - Inhibitory Anx...   svr
# 49  28-Intolerance of Uncertainty - Inhibitory Anx...    kr
# 50  28-Intolerance of Uncertainty - Inhibitory Anx...    en
# 51  28-Intolerance of Uncertainty - Inhibitory Anx...   svr
# 52  28-Intolerance of Uncertainty - Inhibitory Anx...    kr
# 53  28-Intolerance of Uncertainty - Inhibitory Anx...    en

# %%
# change indexes of IU results to update main results DF
results_ern_IU = results_ern_IU.set_index(pd.Index(np.arange(168, 180)))
results_ern.update(results_ern_IU)

# %%
# filter scales of interest
results_ern = results_ern[results_ern['scale'].isin(scales)]

# %% [markdown]
# #### Extract best significant results

# %%
current_results = results_ern

# %%
results_significant = current_results[(current_results['mean_train_r2'] > 0) 
        & (current_results['mean_cv_r2'] >= 0) 
        & (current_results['external_score'] >= 0)  
        & (current_results['p-value'] < 0.05)]

# %% [markdown]
# Extract best significant model for each estimator

# %%
results_idx = results_significant.groupby(['scale', 'model'])['mean_cv_r2'].transform(max) == results_significant['mean_cv_r2']
results_significant_unique = results_significant[results_idx]
results_significant_unique[columns]
# Out:
#      mean_train_r2  mean_cv_r2   p-value  external_score  external_p-value  \
# 1         0.125565    0.068960  0.003996        0.070520          0.017982
# 6         0.061035    0.045102  0.003996        0.014335          0.215784
# 11        0.104305    0.054987  0.008991        0.023258          0.105894
# 47        0.125939    0.090101  0.001998        0.012885          0.124875
# 60        0.049587    0.005228  0.034965        0.006655          0.289710
# 61        0.092647    0.030011  0.015984        0.006548          0.214785
# 142       0.196231    0.055361  0.006993        0.059436          0.057942
# 172       0.175661    0.029852  0.021978        0.047695          0.084915
# 176       0.124229    0.036322  0.013986        0.056105          0.069930
# 190       0.208191    0.071807  0.006993        0.019947          0.093906
# 191       0.187138    0.069042  0.004995        0.020211          0.124875
#
#                                                  scale model
# 1                             16-Rumination Full Scale    kr
# 6                             16-Rumination Full Scale   svr
# 11                            16-Rumination Full Scale    en
# 47                                              07-BIS    en
# 60                   14-Obsessive-Compulsive OBSESSING   svr
# 61                   14-Obsessive-Compulsive OBSESSING    kr
# 142  15-Obsessional Beliefs - Overestimation of threat    kr
# 172  28-Intolerance of Uncertainty - Inhibitory Anx...    kr
# 176  28-Intolerance of Uncertainty - Inhibitory Anx...    en
# 190                06-Self-Esteem Scale_SES Rosenberga    kr
# 191                06-Self-Esteem Scale_SES Rosenberga    en

# %% [markdown]
# #### Extract best (not necessary significant) models for each estimator - based on the highest mean CV score

# %%
results_idx = current_results.groupby(['scale', 'model'])['mean_cv_r2'].transform(max) == current_results['mean_cv_r2']
results_unique_models = current_results[results_idx]

# %%
results_unique_models = results_unique_models.drop_duplicates(subset=['mean_cv_r2', 'model', 'scale'])
results_unique_models[columns]
# Out:
#      mean_train_r2  mean_cv_r2   p-value  external_score  external_p-value  \
# 0         0.293081    0.049043  0.005994       -0.147834          0.378621
# 1         0.125565    0.068960  0.003996        0.070520          0.017982
# 11        0.104305    0.054987  0.008991        0.023258          0.105894
# 13        0.037890   -0.014750  0.125874       -0.077957          0.549451
# 14        0.033512   -0.021767  0.211788       -0.067470          0.710290
# 18        0.108733    0.012977  0.023976       -0.147534          0.274725
# 24        0.347438    0.123885  0.000999       -0.255872          0.818182
# 34        0.212917    0.142738  0.000999       -0.087499          0.379620
# 35        0.198110    0.132219  0.000999       -0.042874          0.298701
# 45        0.095453    0.059871  0.002997       -0.040503          0.243756
# 46        0.172441    0.093590  0.001998       -0.014925          0.205794
# 47        0.125939    0.090101  0.001998        0.012885          0.124875
# 50        0.000000   -0.048387  0.625375       -0.000650          0.733267
# 55        0.000646   -0.048818  0.632368       -0.000599          0.595405
# 57       -0.089895   -0.103875  0.357642       -0.197355          0.280719
# 66        0.207302    0.071799  0.006993       -0.085787          0.448551
# 67        0.124672    0.047615  0.008991       -0.027234          0.353646
# 68        0.043092    0.014135  0.022977       -0.006860          0.440559
# 79        0.179445    0.003505  0.012987       -0.232216          0.521479
# 81        0.027990    0.005853  0.040959       -0.192910          0.763237
# 83        0.004738    0.000049  0.016983       -0.125114          0.698302
# 87        0.069593   -0.001735  0.028971       -0.161933          0.943057
# 88        0.092813    0.004296  0.056943       -0.103933          0.890110
# 89        0.090368    0.004084  0.059940       -0.084118          0.877123
# 102       0.088616    0.024156  0.006993       -0.074879          0.647353
# 103       0.090358    0.020184  0.038961       -0.041568          0.670330
# 104       0.081022    0.020671  0.040959       -0.026217          0.662338
# 117       0.009260   -0.080017  0.024975       -0.407981          0.932068
# 118       0.103207   -0.001015  0.076923       -0.162425          0.923077
# 119       0.105856    0.000471  0.053946       -0.165128          0.916084
# 129       0.037457    0.013701  0.024975       -0.154004          0.936064
# 130       0.045597   -0.007319  0.151848       -0.045322          0.916084
# 131       0.048873   -0.007414  0.150849       -0.036170          0.910090
# 141       0.308373    0.076063  0.004995       -0.064995          0.267732
# 142       0.196231    0.055361  0.006993        0.059436          0.057942
# 143       0.101490    0.005699  0.059940        0.057650          0.037962
# 153       0.030343   -0.002036  0.078921       -0.003376          0.198801
# 154       0.021775   -0.020784  0.325674       -0.000025          0.089910
# 155       0.019743   -0.020921  0.330669       -0.003537          0.090909
# 165       0.249379    0.128003  0.000999       -0.268828          0.286713
# 166       0.280117    0.104785  0.002997       -0.251443          0.316683
# 167       0.114823    0.070385  0.002997       -0.145070          0.497502
# 174       0.155707    0.007049  0.052947        0.025843          0.092907
# 175       0.293927    0.137673  0.000999       -0.038856          0.156843
# 176       0.124229    0.036322  0.013986        0.056105          0.069930
# 189       0.190780    0.050496  0.000999       -0.111440          0.449550
# 190       0.208191    0.071807  0.006993        0.019947          0.093906
# 191       0.187138    0.069042  0.004995        0.020211          0.124875
#
#                                                  scale model
# 0                             16-Rumination Full Scale   svr
# 1                             16-Rumination Full Scale    kr
# 11                            16-Rumination Full Scale    en
# 13                            05-DASS-21 Anxiety scale    kr
# 14                            05-DASS-21 Anxiety scale    en
# 18                            05-DASS-21 Anxiety scale   svr
# 24                                   04-STAI Trait SUM   svr
# 34                                   04-STAI Trait SUM    kr
# 35                                   04-STAI Trait SUM    en
# 45                                              07-BIS   svr
# 46                                              07-BIS    kr
# 47                                              07-BIS    en
# 50                     14-Obsessive-Compulsive WASHING    en
# 55                     14-Obsessive-Compulsive WASHING    kr
# 57                     14-Obsessive-Compulsive WASHING   svr
# 66                   14-Obsessive-Compulsive OBSESSING   svr
# 67                   14-Obsessive-Compulsive OBSESSING    kr
# 68                   14-Obsessive-Compulsive OBSESSING    en
# 79                    14-Obsessive-Compulsive HOARDING    kr
# 81                    14-Obsessive-Compulsive HOARDING   svr
# 83                    14-Obsessive-Compulsive HOARDING    en
# 87                    14-Obsessive-Compulsive ORDERING   svr
# 88                    14-Obsessive-Compulsive ORDERING    kr
# 89                    14-Obsessive-Compulsive ORDERING    en
# 102                   14-Obsessive-Compulsive CHECKING   svr
# 103                   14-Obsessive-Compulsive CHECKING    kr
# 104                   14-Obsessive-Compulsive CHECKING    en
# 117               14-Obsessive-Compulsive NEUTRALIZING   svr
# 118               14-Obsessive-Compulsive NEUTRALIZING    kr
# 119               14-Obsessive-Compulsive NEUTRALIZING    en
# 129                       14-Obsessive-Compulsive FULL   svr
# 130                       14-Obsessive-Compulsive FULL    kr
# 131                       14-Obsessive-Compulsive FULL    en
# 141  15-Obsessional Beliefs - Overestimation of threat   svr
# 142  15-Obsessional Beliefs - Overestimation of threat    kr
# 143  15-Obsessional Beliefs - Overestimation of threat    en
# 153                   18-Thought Suppression Inventory   svr
# 154                   18-Thought Suppression Inventory    kr
# 155                   18-Thought Suppression Inventory    en
# 165  28-Intolerance of Uncertainty - Prospective An...   svr
# 166  28-Intolerance of Uncertainty - Prospective An...    kr
# 167  28-Intolerance of Uncertainty - Prospective An...    en
# 174  28-Intolerance of Uncertainty - Inhibitory Anx...   svr
# 175  28-Intolerance of Uncertainty - Inhibitory Anx...    kr
# 176  28-Intolerance of Uncertainty - Inhibitory Anx...    en
# 189                06-Self-Esteem Scale_SES Rosenberga   svr
# 190                06-Self-Esteem Scale_SES Rosenberga    kr
# 191                06-Self-Esteem Scale_SES Rosenberga    en

# %% [markdown]
# #### Update main results DF with the significant models (they are not necessery models with the highest mean CV score)

# %%
# ERN
indexes = pd.Index([1,0,11,47,66,67,142, 175,176,190,191])

results_significant_unique_updated_with_best_significant = results_significant_unique.set_index(indexes)
results_unique_models.update(results_significant_unique_updated_with_best_significant)

# %% [markdown]
# #### Replace names of scales

# %%
results_unique_models = results_unique_models.replace(scales_dict)

# %% [markdown]
# #### Leave only KR and EN models

# %%
models = ['en', 'kr']
results_unique_models_without_svr = results_unique_models[results_unique_models['model'].isin(models)]

# %% [markdown]
# #### Save results

# %% [markdown]
# - all

# %%
results_unique_models_without_svr.to_pickle("../public_data/results/models_pickles/ern_results_models_full.pkl")

# %% [markdown]
# - extract only most important info

# %%
columns = [ 'scale', 'model', 'mean_train_r2', 'mean_cv_r2', 'p-value', 'external_score', 'external_p-value']

results_unique_models_without_svr[columns].to_csv("../public_data/results/models_results/ern_results_essential.csv")

# %% [markdown]
# - extended summary of results

# %%
columns_extended = ['scale', 'model', 'mean_train_r2', 'mean_train_mse', 'mean_train_mae', 'mean_cv_r2', 'std_cv_r2', 'p-value', 'external_score',  
           'external_p-value' , 'pipeline_name', 'pre_processed_pipeline', 
            'mean_cv_mae', 'std_cv_mae', 'mean_cv_mse', 'std_cv_mse', 'parameters', 'cv_results', 'best_estimator',
          ]

results_extended = results_unique_models_without_svr[columns_extended]

# %% [markdown]
# Add num of PCA components

# %%
results_extended['PCA components num'] = results_extended['pipeline_name'].apply(lambda x: x.split('_')[1])

# %% [markdown]
# Add ROI

# %%
# add column with ROI indicator
results_extended['ROI'] = results_extended['pre_processed_pipeline'].apply(lambda x: 
                                                '1' if x[0].channels_list == ['Fpz', 'AFz', 'Fz', 'FCz', 'Cz', 'CPz', 'P1', 'Pz', 'P2'] else '2')

# %% [markdown]
# Add CV splits scores

# %%
# add columns with exact scores of CV
for index, row in results_extended.iterrows():
    
    best = row.parameters
    index_best = row.cv_results['params'].index(best)
    
    split_1_r2 = row.cv_results['split0_test_r2'][index_best]
    split_2_r2 = row.cv_results['split1_test_r2'][index_best]
    split_3_r2 = row.cv_results['split2_test_r2'][index_best]
    
    results_extended.loc[index, 'split_1_r2'] = split_1_r2
    results_extended.loc[index, 'split_2_r2'] = split_2_r2
    results_extended.loc[index, 'split_3_r2'] = split_3_r2

# %% [markdown]
# Add linear models coefficients

# %%
coef_df = pd.DataFrame(columns=['coef_1', 'coef_2', 'coef_3', 'coef_4'])

for index, row in results_extended[['best_estimator']].iterrows():
    if row.best_estimator.steps[1][0] == 'en':
        estimator = row.best_estimator.steps[1][1]
        coefs = estimator.coef_
        coefs = np.append(coefs, [None] * (4 - len(coefs))) if len(coefs) < 4 else coefs[:4]
        coef_df = coef_df.append(pd.DataFrame([coefs], columns=list(coef_df)), ignore_index=True)
    else:
        coefs = [None] * (4)
        coef_df = coef_df.append(pd.DataFrame([coefs], columns=list(coef_df)), ignore_index=True)

# %%
results_extended = pd.concat([results_extended.reset_index(drop=True), coef_df.reset_index(drop=True)], axis=1)

# %%
results_extended = results_extended.drop(['pipeline_name', 'pre_processed_pipeline', 'cv_results'], axis=1)

# %%
results_extended.to_csv("../public_data/results/models_results/ern_results_extended.csv")

# %% [markdown]
# ## Pe summary

# %%
# extract resulst of IU-Prospective experiment
results_pe_IU = results_pe_IU[results_pe_IU['scale'] == '28-Intolerance of Uncertainty - Prospective Anxiety']
# Out:
#                                                 scale model  mean_train_r2  \
# 27  28-Intolerance of Uncertainty - Prospective An...   svr       0.056174
# 28  28-Intolerance of Uncertainty - Prospective An...    kr       0.073625
# 29  28-Intolerance of Uncertainty - Prospective An...    en       0.071777
# 30  28-Intolerance of Uncertainty - Prospective An...   svr       0.059234
# 31  28-Intolerance of Uncertainty - Prospective An...    kr       0.060687
# 32  28-Intolerance of Uncertainty - Prospective An...    en       0.058377
# 33  28-Intolerance of Uncertainty - Prospective An...   svr       0.069365
# 34  28-Intolerance of Uncertainty - Prospective An...    kr       0.074454
# 35  28-Intolerance of Uncertainty - Prospective An...    en       0.097828
# 36  28-Intolerance of Uncertainty - Prospective An...   svr       0.049634
# 37  28-Intolerance of Uncertainty - Prospective An...    kr       0.069960
# 38  28-Intolerance of Uncertainty - Prospective An...    en       0.075378
# 39  28-Intolerance of Uncertainty - Prospective An...   svr       0.053531
# 40  28-Intolerance of Uncertainty - Prospective An...    kr       0.072976
# 41  28-Intolerance of Uncertainty - Prospective An...    en       0.077831
# 42  28-Intolerance of Uncertainty - Prospective An...   svr      -0.001287
# 43  28-Intolerance of Uncertainty - Prospective An...    kr       0.003179
# 44  28-Intolerance of Uncertainty - Prospective An...    en       0.000000
# 45  28-Intolerance of Uncertainty - Prospective An...   svr       0.040553
# 46  28-Intolerance of Uncertainty - Prospective An...    kr       0.055530
# 47  28-Intolerance of Uncertainty - Prospective An...    en       0.058453
# 48  28-Intolerance of Uncertainty - Prospective An...   svr       0.043460
# 49  28-Intolerance of Uncertainty - Prospective An...    kr       0.059769
# 50  28-Intolerance of Uncertainty - Prospective An...    en       0.062238
# 51  28-Intolerance of Uncertainty - Prospective An...   svr      -0.001288
# 52  28-Intolerance of Uncertainty - Prospective An...    kr       0.001053
# 53  28-Intolerance of Uncertainty - Prospective An...    en       0.000000
#
#     mean_cv_r2   p-value  external_score  external_p-value
# 27    0.026537  0.028971        0.126669          0.009990
# 28    0.029535  0.033966        0.091769          0.020979
# 29    0.030346  0.031968        0.082223          0.019980
# 30    0.016911  0.039960        0.134998          0.013986
# 31    0.013915  0.057942        0.064573          0.024975
# 32    0.016608  0.053946        0.046847          0.023976
# 33    0.024546  0.024975        0.092814          0.034965
# 34    0.023279  0.040959        0.042899          0.051948
# 35    0.025752  0.025974        0.054578          0.056943
# 36    0.025317  0.027972        0.116312          0.008991
# 37    0.024232  0.038961        0.115211          0.008991
# 38    0.026510  0.026973        0.126955          0.007992
# 39    0.015130  0.043956        0.116921          0.010989
# 40    0.015854  0.051948        0.115604          0.012987
# 41    0.020277  0.034965        0.125309          0.007992
# 42   -0.002912  0.066933       -0.028821          0.185814
# 43   -0.004984  0.109890       -0.036955          0.024975
# 44   -0.004878  0.108891       -0.041978          0.910090
# 45    0.007857  0.056943        0.117074          0.008991
# 46    0.011049  0.058941        0.098174          0.013986
# 47    0.013335  0.042957        0.108480          0.009990
# 48    0.002303  0.064935        0.103395          0.014985
# 49    0.003710  0.070929        0.095653          0.016983
# 50    0.006363  0.047952        0.106016          0.012987
# 51   -0.002913  0.066933       -0.028823          0.458541
# 52   -0.005352  0.115884       -0.043058          0.043956
# 53   -0.004878  0.113886       -0.041978          0.910090

# %%
results_full_pe = pd.concat([results_pe.reset_index(drop=True), results_pe_IU.reset_index(drop=True)], axis=0)

# %%
# filter scales of interest
results_full_pe = results_full_pe[results_full_pe['scale'].isin(scales)]

# %% [markdown]
# #### Extract best models for each estimator - based on the highest mean CV score

# %%
current_results = results_full_pe

# %%
results_idx = current_results.groupby(['scale', 'model'])['mean_cv_r2'].transform(max) == current_results['mean_cv_r2']
results_unique_models = current_results[results_idx]

# %%
results_unique_models = results_unique_models.drop_duplicates(subset=['mean_cv_r2', 'model', 'scale'])
results_unique_models[columns]
# Out:
#                                                  scale model  mean_train_r2  \
# 0                             16-Rumination Full Scale   svr       0.098618
# 1                             16-Rumination Full Scale    kr       0.095524
# 2                             16-Rumination Full Scale    en       0.092549
# 30                            05-DASS-21 Anxiety scale   svr       0.015114
# 32                            05-DASS-21 Anxiety scale    en       0.026282
# 34                            05-DASS-21 Anxiety scale    kr       0.053761
# 40                                   04-STAI Trait SUM    kr       0.046953
# 41                                   04-STAI Trait SUM    en       0.050579
# 42                                   04-STAI Trait SUM   svr       0.025869
# 61                                              07-BIS    kr       0.044284
# 62                                              07-BIS    en       0.047343
# 66                                              07-BIS   svr       0.015879
# 74                     14-Obsessive-Compulsive WASHING    en       0.000000
# 76                     14-Obsessive-Compulsive WASHING    kr       0.321525
# 87                     14-Obsessive-Compulsive WASHING   svr      -0.061743
# 90                   14-Obsessive-Compulsive OBSESSING   svr       0.007707
# 92                   14-Obsessive-Compulsive OBSESSING    en       0.012376
# 94                   14-Obsessive-Compulsive OBSESSING    kr       0.034435
# 114                   14-Obsessive-Compulsive HOARDING   svr       0.003441
# 115                   14-Obsessive-Compulsive HOARDING    kr       0.029838
# 116                   14-Obsessive-Compulsive HOARDING    en       0.020164
# 128                   14-Obsessive-Compulsive ORDERING    en       0.000000
# 129                   14-Obsessive-Compulsive ORDERING   svr      -0.003421
# 130                   14-Obsessive-Compulsive ORDERING    kr       0.000680
# 145                   14-Obsessive-Compulsive CHECKING    kr       0.000598
# 146                   14-Obsessive-Compulsive CHECKING    en       0.000000
# 150                   14-Obsessive-Compulsive CHECKING   svr       0.002924
# 164               14-Obsessive-Compulsive NEUTRALIZING    en       0.000000
# 165               14-Obsessive-Compulsive NEUTRALIZING   svr      -0.048351
# 172               14-Obsessive-Compulsive NEUTRALIZING    kr      -0.001815
# 181                       14-Obsessive-Compulsive FULL    kr       0.000183
# 182                       14-Obsessive-Compulsive FULL    en       0.000000
# 183                       14-Obsessive-Compulsive FULL   svr      -0.005810
# 201  15-Obsessional Beliefs - Overestimation of threat   svr       0.045430
# 205  15-Obsessional Beliefs - Overestimation of threat    kr       0.043399
# 206  15-Obsessional Beliefs - Overestimation of threat    en       0.029768
# 219                   18-Thought Suppression Inventory   svr       0.015316
# 220                   18-Thought Suppression Inventory    kr       0.022653
# 221                   18-Thought Suppression Inventory    en       0.024353
# 238  28-Intolerance of Uncertainty - Prospective An...    kr       0.075035
# 239  28-Intolerance of Uncertainty - Prospective An...    en       0.073495
# 240  28-Intolerance of Uncertainty - Prospective An...   svr       0.055649
# 253  28-Intolerance of Uncertainty - Inhibitory Anx...    kr       0.009100
# 254  28-Intolerance of Uncertainty - Inhibitory Anx...    en       0.006268
# 255  28-Intolerance of Uncertainty - Inhibitory Anx...   svr      -0.017671
# 276                06-Self-Esteem Scale_SES Rosenberga   svr       0.061499
# 277                06-Self-Esteem Scale_SES Rosenberga    kr       0.081662
# 278                06-Self-Esteem Scale_SES Rosenberga    en       0.073095
#
#      mean_cv_r2   p-value  external_score  external_p-value
# 0      0.052768  0.005994        0.108485          0.024975
# 1      0.046113  0.011988        0.102511          0.015984
# 2      0.047671  0.011988        0.099433          0.007992
# 30    -0.027174  0.126873       -0.089960          0.696304
# 32    -0.024291  0.313686       -0.048449          0.893107
# 34    -0.002676  0.079920       -0.083297          0.878122
# 40     0.008272  0.042957        0.017547          0.155844
# 41     0.008187  0.044955        0.017972          0.130869
# 42     0.006716  0.039960        0.014660          0.146853
# 61     0.009674  0.049950        0.052883          0.052947
# 62     0.010798  0.044955        0.048408          0.052947
# 66     0.012535  0.015984        0.035246          0.122877
# 74    -0.048387  0.621379       -0.000650          0.733267
# 76    -0.034655  0.060939       -0.285496          0.548452
# 87    -0.103034  0.181818       -0.207208          0.161838
# 90    -0.008127  0.114885       -0.012089          0.841159
# 92    -0.006290  0.152847       -0.004104          0.481518
# 94     0.002304  0.083916       -0.046862          0.836164
# 114   -0.000790  0.012987       -0.155072          0.171828
# 115    0.003237  0.055944       -0.117605          0.615385
# 116    0.003646  0.031968       -0.114503          0.421578
# 128   -0.050335  0.609391       -0.005175          0.726274
# 129   -0.055049  0.654346       -0.006395          0.003996
# 130   -0.050739  0.646354       -0.006321          0.904096
# 145   -0.002069  0.048951       -0.012466          0.783217
# 146   -0.001789  0.050949       -0.011281          0.898102
# 150   -0.003598  0.021978       -0.000727          0.303696
# 164   -0.070365  0.732268       -0.032521          0.734266
# 165   -0.215840  0.491508       -0.321062          0.328671
# 172   -0.066601  0.728272       -0.042352          0.198801
# 181   -0.016347  0.311688       -0.001261          0.974026
# 182   -0.015445  0.300699       -0.000586          0.838162
# 183   -0.010129  0.191808       -0.003620          0.320679
# 201   -0.017796  0.158841       -0.044934          0.580420
# 205   -0.005979  0.129870       -0.048114          0.814186
# 206   -0.006192  0.134865       -0.023329          0.821179
# 219   -0.000724  0.084915        0.018526          0.010989
# 220   -0.014862  0.215784        0.022427          0.034965
# 221   -0.014472  0.209790        0.017295          0.033966
# 238    0.045331  0.012987        0.101724          0.020979
# 239    0.045494  0.012987        0.091518          0.022977
# 240    0.046577  0.006993        0.194465          0.008991
# 253   -0.032846  0.433566       -0.023943          0.806194
# 254   -0.033303  0.442557       -0.015074          0.816184
# 255   -0.025167  0.168831       -0.000434          0.341658
# 276   -0.003993  0.018981       -0.123548          0.653347
# 277   -0.001863  0.081918       -0.076364          0.609391
# 278   -0.002769  0.089910       -0.046646          0.612388

# %% [markdown]
# #### Replace names of scales

# %%
results_unique_models = results_unique_models.replace(scales_dict)

# %% [markdown]
# #### Leave only KR and EN models

# %%
models = ['en', 'kr']
results_unique_models_without_svr = results_unique_models[results_unique_models['model'].isin(models)]

# %% [markdown]
# #### Save results

# %% [markdown]
# - all

# %%
results_unique_models_without_svr.to_pickle("../public_data/results/models_pickles/pe_results_models_full.pkl")

# %% [markdown]
# - extract only most important info

# %%
columns = [ 'scale', 'model', 'mean_train_r2', 'mean_cv_r2', 'p-value', 'external_score', 'external_p-value']

results_unique_models_without_svr[columns].to_csv("../public_data/results/models_results/pe_results_essential.csv")

# %% [markdown]
# - extended summary of results

# %%
columns_extended = ['scale', 'model', 'mean_train_r2', 'mean_train_mse', 'mean_train_mae', 'mean_cv_r2', 'std_cv_r2', 'p-value', 'external_score',  
           'external_p-value' , 'pipeline_name', 'pre_processed_pipeline', 
            'mean_cv_mae', 'std_cv_mae', 'mean_cv_mse', 'std_cv_mse', 'parameters', 'cv_results', 'best_estimator',
          ]

results_extended = results_unique_models_without_svr[columns_extended]

# %% [markdown]
# Add num of PCA components

# %%
results_extended['PCA components num'] = results_extended['pipeline_name'].apply(lambda x: x.split('_')[1])

# %% [markdown]
# Add ROI

# %%
results_extended['ROI'] = results_extended['pre_processed_pipeline'].apply(lambda x: 
                                                '1' if x[0].channels_list == ['Fpz', 'AFz', 'Fz', 'FCz', 'Cz', 'CPz', 'P1', 'Pz', 'P2'] else '2')

# %% [markdown]
# Add CV splits scores

# %%
for index, row in results_extended.iterrows():
    
    best = row.parameters
    index_best = row.cv_results['params'].index(best)
    
    split_1_r2 = row.cv_results['split0_test_r2'][index_best]
    split_2_r2 = row.cv_results['split1_test_r2'][index_best]
    split_3_r2 = row.cv_results['split2_test_r2'][index_best]
    
    results_extended.loc[index, 'split_1_r2'] = split_1_r2
    results_extended.loc[index, 'split_2_r2'] = split_2_r2
    results_extended.loc[index, 'split_3_r2'] = split_3_r2

# %% [markdown]
# Add linear models coefficients

# %%
coef_df = pd.DataFrame(columns=['coef_1', 'coef_2', 'coef_3', 'coef_4'])

for index, row in results_extended[['best_estimator']].iterrows():
    if row.best_estimator.steps[1][0] == 'en':
        estimator = row.best_estimator.steps[1][1]
        coefs = estimator.coef_
        coefs = np.append(coefs, [None] * (4 - len(coefs))) if len(coefs) < 4 else coefs[:4]
        coef_df = coef_df.append(pd.DataFrame([coefs], columns=list(coef_df)), ignore_index=True)
    else:
        coefs = [None] * (4)
        coef_df = coef_df.append(pd.DataFrame([coefs], columns=list(coef_df)), ignore_index=True)

# %%
results_extended = pd.concat([results_extended.reset_index(drop=True), coef_df.reset_index(drop=True)], axis=1)

# %%
results_extended = results_extended.drop(['pipeline_name', 'pre_processed_pipeline', 'cv_results'], axis=1)

# %%
results_extended.to_csv("../public_data/results/models_results/pe_results_extended.csv")
